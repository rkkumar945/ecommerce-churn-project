# %% [markdown]
# Section A: basic queries + aggregation.

# %%
#1.Top 5 countries dikhao (UK ke alawa) jinka total revenue sabse zyada hai, saath mein unka total order count bhi dikhao.

# %%
#

# %%
#2.CASE WHEN use karke customers ko 3 categories mein classify karo: "High Spender" (>2000), "Medium Spender" (500-2000), "Low Spender" (<500) — aur har category mein kitne customers hain COUNT karo.

# %%
#

# %% [markdown]
# Section B: JOINSs

# %%
#3.Un customers ko dhoondo (LEFT JOIN + IS NULL use karke) jinka koi order nahi hai — agar result empty aaye to bhi likho "kyun empty aaya" apne shabdon mein.

# %%
#

# %%
#4.INNER JOIN karke un countries ka naam nikaalo jinke total customers 50 se zyada hain aur average order value 300 se zyada hai (JOIN + GROUP BY + HAVING combine karke).

# %%
#

# %% [markdown]
# Section C: window functions

# %%
#5.Har country ke top 3 customers nikaalo (by total spend) — RANK() use karke, ties bhi handle honi chahiye.

# %%
#

# %%
#6.Har customer ke consecutive orders ke beech ka average gap (days) nikaalo (LAG() + julianday()), aur sirf un customers ko dikhao jinka average gap 120 din se zyada hai.

# %%
#

# %%
#7.NTILE(4) se customers ko quartiles mein baanto, aur har quartile ka average total_spend aur average total_orders dono ek saath dikhao.

# %%
#

# %% [markdown]
# Section D: CTEs

# %%
#8.Ek chained CTE banao jo: Step 1 mein har customer ka Frequency+Monetary nikale, Step 2 mein Recency add kare (last order se 2011-12-10 tak ka gap), aur final output mein sirf un customers ko dikhaye jinka Monetary > 1000 aur Recency > 100 din.

# %%
#

# %% [markdown]
# Section E: Missing values + optimization

# %%
#9.Description column mein missing values ka percentage nikaalo, aur check karo ki yeh missing values kisi specific Country mein zyada concentrated hain ya sab jagah evenly spread hain.

# %%
#

# %%
#10.EXPLAIN QUERY PLAN use karke check karo ki Sawal 5 (top-3-per-country) wali query index ke bina kaisi perform karti hai — phir ek relevant index banao aur dobara check karo ki plan change hua ya nahi.

# %%
#

# %% [markdown]
# Section F: Conceptual (no code only theory)

# %% [markdown]
# 11.RANK(), DENSE_RANK(), aur ROW_NUMBER() mein fark 2-3 lines mein explain karo, ek chhota example ke saath.

# %% [markdown]
# Ans:

# %% [markdown]
# 12.CTE aur Subquery mein kya fark hai, aur tum kab CTE choose karoge subquery ke bajaye?

# %% [markdown]
# Ans:

# %%
SELECT COUNT(*) AS total_rows,
       MIN(InvoiceDate) AS first_date,
       MAX(InvoiceDate) AS last_date
FROM transactions;
