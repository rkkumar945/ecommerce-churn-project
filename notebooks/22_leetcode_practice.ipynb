# %% [markdown]
# 5 leetcode problems

# %% [markdown]
# 1.Two Sum(Leetcode 1) - ek list of numbers aur ek target diya hai, do numbers dhoondo jinka sum target ke barabar ho. (Dictionary/hashmap use karna seekhoge — bahut common interview pattern hai)

# %%
#

# %% [markdown]
# 2.Contains Duplicate (LeetCode #217) — ek list mein koi bhi value repeat ho rahi hai ya nahi check karo. (Yahan set() ka use hoga — Day 21 wala concept)

# %%
#

# %% [markdown]
# 3.Valid Anagram (LeetCode #242) — do strings anagram hain ya nahi check karo (jaise "listen" aur "silent"). (Dictionary/counting practice)

# %%
#

# %% [markdown]
# 4.Merge Two Sorted Lists to Array (chhota custom version — do sorted lists ko ek sorted list mein merge karo, apna khud ka function likh kar, bina sorted() built-in use kiye). (Loop + comparison logic)

# %%
#

# %% [markdown]
# 5.Group Anagrams (LeetCode #49, thoda harder — agar time bache) — strings ki list ko unke anagram groups mein baanto. (Dictionary of lists — Day 22 ka nested structure concept)

# %%
#
