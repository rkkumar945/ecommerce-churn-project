# %%
import sqlite3
conn = sqlite3.connect('../data/db/ecommerce.db') # conn ko connection object kehte hai.
print("database connection successfully")
conn.close() #ye method database connection ko securly close kar deta hai, jis se memory leaks nahi hoti or data corruption ka risk bhi nahi rahta.
# Out:
# database connection successfully
