# %% [markdown]
# Section A: Python Basics (Lists, Dicts, Loops, Functions)

# %% [markdown]
# 1.Ek function likho categorize_customer(total_spend) jo return kare "VIP" (>5000), "Regular" (1000-5000), ya "New" (<1000).

# %%
#

# %% [markdown]
# 2.Ek dictionary banao 5 customers ka ({customer_id: total_spend}), aur loop chala kar har customer ke liye upar wala function call karke unki category print karo.

# %%
#

# %% [markdown]
# 3.Do lists diye gaye hain: quantities = [10, 25, 5, 40] aur prices = [6.5, 2.1, 15.0, 3.75]. Bina NumPy use kiye (sirf loop se), har order ka revenue calculate karo aur total revenue print karo.

# %%
#

# %% [markdown]
# Section B: NumPy

# %% [markdown]
# 4.Ek NumPy array banao 15 random order values ka (np.random.randint(50, 5000, size=15)). Uska mean, median, aur standard deviation nikaalo.

# %%
#

# %% [markdown]
# 5.Usi array se boolean indexing use karke sirf woh values nikaalo jo mean se zyada hain.

# %%
#

# %% [markdown]
# 6.25th aur 75th percentile nikaalo, aur unke beech ka difference (IQR) calculate karo.

# %%
#

# %% [markdown]
# 7.np.where() use karke ek naya array banao jisme har value ko "High" (>1000) ya "Low" (<=1000) label diya ho.

# %%
#

# %% [markdown]
# Section C: APIs/HTTP/JSON

# %% [markdown]
# 8.https://jsonplaceholder.typicode.com/todos/1 par GET request bhejo, response ka status_code print karo, aur JSON response se title field nikaalo.

# %%
#

# %% [markdown]
# 9.Ek Python dictionary banao (apna khud ka "customer churn request" jaisa structure — kam se kam 4 fields ke saath, ek nested field bhi ho jaise orders: [...]), phir use json.dumps(..., indent=4) se pretty-print karo.

# %%
#

# %% [markdown]
# 10.Explain karo (apne shabdon mein, comment ke roop mein): GET aur POST mein kya fark hai, aur JSON format ka structure Python dictionary se kaise milta-julta hai.

# %%
#

# %% [markdown]
# Tips :
# 1.Sawal 3 mein loop ka result Sawal 4-7 ke NumPy approach se compare karo — dekhoge NumPy kitna concise aur fast hai.
#
# 2.Sawal 8 mein agar internet issue ho to error handling (try/except) bhi dikhana.
