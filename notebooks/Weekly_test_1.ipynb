# %%
#01:Total kitni rows hai dataset me , or unme se kitni rows me Customer ID missing hai.

# %%
#

# %%
#02:United Kingdom ke alawa sabse jyada transactions kis country se aaye hai.(top 5 dikhao)

# %%
#

# %%
#03:sabse mehenga(highest Price) product kon sa hai, or uska Description kya hai.

# %%
#

# %%
#04:aise sare orders nikalo jinki Quantity negative hai(returns ka signal)- kitni rows hai.

# %%
#

# %%
#05:Customer ID = 14646 (ya koi bhi ek valid Customer ID jo tumhe data me mile) ke sare orders InvoiceDate ke hisab se ascending order me dikhao.

# %%
#

# %%
#06:Har Country ke liye average Price nikalo or sirf unhi countries ko dikhao jinka average price 5 se jyada hai(HAVING use karke).

# %%
#

# %%
#07:2010 saal me total kitne unique invoices(orders) bane hai.

# %%
#

# %%
#08:Sabse jyada quantity(total units) purchase karne wale top 5 customers kon hai (Customer ID ke hisab se, Customer ID IS NOT NULL rakhna).

# %%
#

# %%
#09:Invoice number 'C' se start hone wale (cancellations) sabse jyada kis country me hote hai.

# %%
#

# %%
#10:ek query likho jo StockCOde, uska total sales revenue (Quantity * Price), or total orders count ek sath dikhaye - sirf top 10 products by revenue.

# %%
#

# %%
#practice questions

# %%
#Sabse zyada Quantity wala single order kaunsa tha?

# %%
#

# %%
#Germany ke customers ke top 5 sabse expensive items kaunse hain?

# %%
#

# %%
#2011 ke December mein hue orders kitne the? (InvoiceDate LIKE '2011-12%')

# %%
#

# %%
#Kaunsa customer sabse zyada baar order karta hai (COUNT DISTINCT Invoice per Customer ID)?

# %%
#

# %%
#Kaunse products sabse zyada return/cancel (Invoice 'C') hote hain?

# %%
#

# %%
#Har month mein kitne total orders hue (InvoiceDate se month extract karke)?

# %%
#

# %%
#ye  upar wale sare questions 04_group_by_having tak ke hai.
