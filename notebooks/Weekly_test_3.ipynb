# %%
#1:Har country ka top 2 customer (by total spend) nikaalo — ek single query mein, jisme sirf woh 2 customers dikhein har country ke liye (ties ko bhi handle karna, matlab agar 2nd aur 3rd position tie ho to dono dikhne chahiye).
#(Hint: RANK() use karo, ROW_NUMBER() nahi — kyunki RANK ties ko same position deta hai)

# %%
#

# %%
#02:Har customer ke consecutive orders ke beech ka gap (days) nikaalo, aur phir un customers ko dhoondo jinka average gap 90 din se zyada hai — yeh potential churners hain (Recency-based churn logic ka preview).
#(Hint: LAG() + julianday() + outer GROUP BY/HAVING)

# %%
#

# %%
#03:Ek query likho jo har customer ka running total (cumulative spend, order date ke hisaab se) nikaale, aur saath mein yeh bhi dikhaye ki total kitne % tak pahuncha hai uske apne final total spend ka (matlab: running_total / final_total * 100).
#(Hint: do window functions ek saath — SUM() OVER (... ORDER BY ...) aur SUM() OVER (PARTITION BY ... ) bina ORDER BY ke, jo poora total degi)

# %%
#

# %%
#04:NTILE(4) se customers ko quartiles mein baanto (spend ke hisaab se), phir har quartile ka average order count aur average total spend dono nikaalo ek hi summary table mein (matlab outer query mein GROUP BY quartile).

# %%
#

# %%
#05:Month-over-month revenue growth % nikaalo (LAG() use karke), aur phir sirf woh months dikhao jaha growth negative thi (revenue pichle mahine se kam hua) — growth % bhi column mein dikhna chahiye.
#(Hint: (current - previous) / previous * 100, division by zero se bachne ke liye previous NULL/0 check karna)

# %%
#

# %%
#Tips:

#:Har sawal mein pehle chhota sample (LIMIT 20) print karke dekho ki logic sahi lag raha hai, phir pura result nikaalo.
#:Sawal 3 aur 5 mein "divide by zero" ya "NULL" issues aa sakte hain — un edge cases ko handle karna (jaise CASE WHEN previous_val = 0 THEN NULL ELSE ... END) practice ka hi hissa hai.
