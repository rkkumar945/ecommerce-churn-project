# %%
#01:customers aur orders table ko INNER JOIN karke, sirf France ke customers ke saare orders (Invoice, OrderValue) dikhao.

# %%
#

# %%
#02:LEFT JOIN use karke countries_ref table ke saath — pata karo kaunse countries (jo reference table mein hain) ka koi bhi customer nahi hai actual data mein.

# %%
#

# %%
#03:INNER JOIN + GROUP BY combine karke, har country ka average order value nikaalo aur sirf top 5 countries dikhao (highest average ke hisaab se).

# %%
#

# %%
#4:Ek query likho jo customers aur orders ko JOIN karke un customers ko dikhaye jinka koi bhi order nahi hai (hint: LEFT JOIN + WHERE ... IS NULL).

# %%
#

# %%
#05:FULL OUTER JOIN (ya uska workaround) use karke countries_ref aur customers ke beech — dono taraf ke unmatched rows ek saath dikhao.

# %%
#

# %%
#06:CROSS JOIN use karke ek chhota example banao: 3 countries × 3 products ka combination table (sirf demo — sample rows use karna, poori table nahi).

# %%
#

# %%
#07:INNER JOIN karke top 10 customers dikhao jinka total order value sabse zyada hai, saath mein unka Country bhi dikhana.

# %%
#

# %%
#08:orders table mein Germany ke customers ke sirf woh orders dikhao jinki OrderValue > 500 — JOIN + WHERE dono use karke.

# %%
#

# %%
#09:Ek query likho jo customers ko unke Country ke saath JOIN kare aur Country-wise total customers aur total orders dono ek saath COUNT kare (JOIN + GROUP BY + COUNT DISTINCT).

# %%
#

# %%
#10:Explain karo (comment ke roop mein notebook mein likho): INNER JOIN, LEFT JOIN, aur FULL OUTER JOIN ke result mein basic fark kya hota hai — apne khud ke examples ke result dekh kar apne shabdon mein likhna.

# %%
#
