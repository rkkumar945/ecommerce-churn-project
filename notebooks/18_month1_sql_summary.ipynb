# %%
#Complete month ka revision.

# %%
## Month 1 SQL Summary — Rajat Kumar

### 1. Basic Queries (Day 4-5)
#- SELECT, WHERE, ORDER BY, GROUP BY, HAVING

### 2. JOINS (Day 6-9)
#- INNER, LEFT, RIGHT, FULL OUTER, CROSS JOIN

### 3. Missing Values (Day 10)
#- NULL identification, CASE WHEN counting
#- Key finding: Customer ID missing ~22.8%

### 4. Window Functions (Day 11-15)
#- OVER(), PARTITION BY, ROW_NUMBER, RANK, DENSE_RANK, NTILE, LAG, LEAD

### 5. CTEs (Day 16-17)
#- WITH clause, chained CTEs

### 6. Optimization (Day 18)
#- Indexing, EXPLAIN QUERY PLAN

# %%
#Key learnings:-

# %%
#1.Window Functions se group-level aur row-level data ek saath mil sakta hai.

# %%
#2.CTEs se complex queries readable ban jaati hain.

# %%
#3.Index se query speed bahut improve hoti hai bade tables par.
